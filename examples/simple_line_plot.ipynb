# %%
rng = client.ranges.retrieve("October 28 Gooster")

# %%
rng2 = client.ranges.create(
    name="October 28 Gooster - Interesting", 
    time_range=sy.TimeRange(1698627771501015300, 1698627795457805600),
    retrieve_if_name_exists=True
)

rng.meta_data.set("key", "value")
rng.meta_data["key"] = "value"
print(rng.meta_data["key"])

plt.plot(rng2.gse_time, rng2.gse_pressure_20)
# Out:
# value
