# %%
import synnax as sy
import matplotlib.pyplot as plt

client = sy.Synnax()

tr = client.ranges.retrieve("07:25 Bang Bang TPC Sim")

plt.plot(tr["daq_time"], tr["gse_ai_1"])

# %%
# %%sql

# %%
-0.384615
